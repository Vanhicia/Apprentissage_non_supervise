# %%
from scipy.io import arff
from sklearn import cluster
from sklearn import metrics
import numpy as np
from matplotlib import pyplot as plt
import time

list_dataset = ["convexe_bien_separe", "carre", "convexe_mal_separe", "bruite_convexe", "densite_variable", "non_convexe"]
path = "./data/"

print("----------Clustering agglomératif----------")
k_list = [20, 9, 30, 2, 4, 10, 2]

link=["single", "average", "complete", "ward"]

# nombre de cluters k indiqué
print("-----Nombre de clusters indiqué-----")

for i in range(len(list_dataset)):
    print("Dataset %d"%i)
    print(list_dataset[i])
    
    print("k = %d"%k_list[i])
    
    dataset = arff.loadarff(open(path + list_dataset[i] + '.arff', 'r'))
    data = [[x[0],x[1]] for x in dataset[0]]

    for j in range(len(link)):
        print("linkage = %s"%link[j])
    
        time_start = time.process_time() # On regarde le temps CPU
    
        clust = cluster.AgglomerativeClustering(n_clusters=k_list[i], affinity='euclidean', linkage=link[j])
        y_pred = clust.fit_predict(data)
        
        time_stop = time.process_time() # On regarde le temps CPU
        
        print("Temps de calcul : " + str(time_stop-time_start))
        
        #print("Score")
        #print(clust.score(data))

        labels = clust.labels_
        print("Indice de Davies-Bouldin")
        print(metrics.davies_bouldin_score(data, labels))

        print("Coefficient de silhouette")
        print(metrics.silhouette_score(data, labels, metric='euclidean'))

        plt.scatter((dataset[0])['x'], (dataset[0])['y'], c=y_pred, cmap="tab20")
        plt.show()
        
        print("\n\n")
        
        
        
        
# nombre de cluters non indiqué
print("-----Nombre de clusters non indiqué : méthode itérative-----")

for i in range(len(list_dataset)):
    print("Dataset %d"%i)
    print(list_dataset[i])
    
    if (list_dataset[i]=="non_convexe"):
        print("dataset non convexe")
    else:
        print("dataset convexe")
        
    print("k attendu = %d"%k_list[i])
    
    dataset = arff.loadarff(open(path + list_dataset[i] + '.arff', 'r'))
    data = [[x[0],x[1]] for x in dataset[0]]

    for j in range(len(link)):
        print("linkage = %s"%link[j])
        db_score_list = []
        sil_score_list = []
        
        for k in range(2,41,1):
    
            clust = cluster.AgglomerativeClustering(n_clusters=k, affinity='euclidean', linkage=link[j])
            y_pred = clust.fit_predict(data)

            #print("Score")
            #print(clust.score(data))

            labels = clust.labels_
            # Indice de Davies-Bouldin"
            db_score = metrics.davies_bouldin_score(data, labels)
            db_score_list.append(db_score)

            # Coefficient de silhouette
            sil_score = metrics.silhouette_score(data, labels, metric='euclidean')
            sil_score_list.append(sil_score)
 
        plt.plot(range(len(db_score_list)), db_score_list)
        plt.xlabel("Nombre de clusters k")
        plt.ylabel("Indice de Davies Bouldin")
        plt.title("Indice de Davies Bouldin en fonction du nombre de clusters k :")
        plt.show()

        plt.plot(range(len(sil_score_list)), sil_score_list)
        plt.xlabel("Nombre de clusters k")
        plt.ylabel("Coefficient de silhouette")
        plt.title("Coefficient de silhouette en fonction du nombre de clusters k :")
        plt.show()
# Out:
# ----------Clustering agglomératif----------
# -----Nombre de clusters indiqué-----
# Dataset 0
# convexe_bien_separe
# k = 20
# linkage = single
# Temps de calcul : 0.005577326999997467
# Indice de Davies-Bouldin
# 0.3235579871203071
# Coefficient de silhouette
# 0.7489964116708273
# linkage = average
# Temps de calcul : 0.01258745800001293
# Indice de Davies-Bouldin
# 0.32355798712030714
# Coefficient de silhouette
# 0.7489964116708273
# linkage = complete
# Temps de calcul : 0.012681528000001663
# Indice de Davies-Bouldin
# 0.32370207649182203
# Coefficient de silhouette
# 0.7481682153149001
# linkage = ward
# Temps de calcul : 0.023080161999999405
# Indice de Davies-Bouldin
# 0.3235579871203071
# Coefficient de silhouette
# 0.7489964116708273
# Dataset 1
# carre
# k = 9
# linkage = single
# Temps de calcul : 0.048694578999999294
# Indice de Davies-Bouldin
# 0.9671115116873137
# Coefficient de silhouette
# -0.08169359083576029
# linkage = average
# Temps de calcul : 0.11054751999999723
# Indice de Davies-Bouldin
# 0.5541197660738013
# Coefficient de silhouette
# 0.5481688245465259
# linkage = complete
# Temps de calcul : 0.10417919700000766
# Indice de Davies-Bouldin
# 0.552997094994944
# Coefficient de silhouette
# 0.548678995573904
# linkage = ward
# Temps de calcul : 0.18577304900000513
# Indice de Davies-Bouldin
# 0.5543846408299329
# Coefficient de silhouette
# 0.5479013817001807
# Dataset 2
# convexe_mal_separe
# k = 30
# linkage = single
# Temps de calcul : 0.05534161500000323
# Indice de Davies-Bouldin
# 1.209671002015401
# Coefficient de silhouette
# -0.38067874639064714
# linkage = average
# Temps de calcul : 0.13219209499999351
# Indice de Davies-Bouldin
# 0.5672998946200345
# Coefficient de silhouette
# 0.5550144030985833
# linkage = complete
# Temps de calcul : 0.1288665249999923
# Indice de Davies-Bouldin
# 0.5588565838365422
# Coefficient de silhouette
# 0.5583384827078943
# linkage = ward
# Temps de calcul : 0.18956460900000138
# Indice de Davies-Bouldin
# 0.5539703648101987
# Coefficient de silhouette
# 0.5622950451008946
# Dataset 3
# bruite_convexe
# k = 2
# linkage = single
# Temps de calcul : 0.0019921880000026704
# Indice de Davies-Bouldin
# 0.5564016388206768
# Coefficient de silhouette
# 0.4843303261448591
# linkage = average
# Temps de calcul : 0.00340024800000549
# Indice de Davies-Bouldin
# 0.7681938515619305
# Coefficient de silhouette
# 0.49328753602785436
# linkage = complete
# Temps de calcul : 0.0033521390000004203
# Indice de Davies-Bouldin
# 0.6994540351379255
# Coefficient de silhouette
# 0.5673612475963945
# linkage = ward
# Temps de calcul : 0.0033303849999981594
# Indice de Davies-Bouldin
# 0.70872268793218
# Coefficient de silhouette
# 0.5573535228050098
# Dataset 4
# densite_variable
# k = 4
# linkage = single
# Temps de calcul : 0.006147417000008204
# Indice de Davies-Bouldin
# 0.5871727117137286
# Coefficient de silhouette
# -0.015556392199301652
# linkage = average
# Temps de calcul : 0.01771906399999068
# Indice de Davies-Bouldin
# 0.5410845560013089
# Coefficient de silhouette
# 0.5806129867355734
# linkage = complete
# Temps de calcul : 0.016041244000007282
# Indice de Davies-Bouldin
# 0.5348844152741853
# Coefficient de silhouette
# 0.5804785072218802
# linkage = ward
# Temps de calcul : 0.021639505999999642
# Indice de Davies-Bouldin
# 0.5375702885505091
# Coefficient de silhouette
# 0.5798059048371337
# Dataset 5
# non_convexe
# k = 10
# linkage = single
# Temps de calcul : 0.10085405200000253
# Indice de Davies-Bouldin
# 1.2222442266099143
# Coefficient de silhouette
# -0.22226475463296197
# linkage = average
# Temps de calcul : 0.30260169100000667
# Indice de Davies-Bouldin
# 0.5984519539370404
# Coefficient de silhouette
# 0.4929635080802633
# linkage = complete
# Temps de calcul : 0.27154573400000004
# Indice de Davies-Bouldin
# 0.6109292446527685
# Coefficient de silhouette
# 0.44792956611978263
# linkage = ward
# Temps de calcul : 0.4466798340000082
# Indice de Davies-Bouldin
# 0.6074794858579053
# Coefficient de silhouette
# 0.4712669665613925
# -----Nombre de clusters non indiqué : méthode itérative-----
# Dataset 0
# convexe_bien_separe
# dataset convexe
# k attendu = 20
# linkage = single
# linkage = average
# linkage = complete
# linkage = ward
# Dataset 1
# carre
# dataset convexe
# k attendu = 9
# linkage = single
# linkage = average
# linkage = complete
# linkage = ward
# Dataset 2
# convexe_mal_separe
# dataset convexe
# k attendu = 30
# linkage = single
# linkage = average
# linkage = complete
# linkage = ward

# %%
import hdbscan
from sklearn.datasets import make_blobs

from scipy.io import arff
from sklearn import cluster
from sklearn import metrics
import numpy as np
from matplotlib import pyplot as plt


list_dataset = ["convexe_petites_taches", "bruite_convexe", "densite_variable", "mal_separe", "non_convexe"]
path = "./data/"

print("----------HDBSCAN----------")
k_list = [30, 2, 4, 10, 2]


for i in range(len(list_dataset)):
    print("Dataset %d"%i)
    print(list_dataset[i])
    
    print("k = %d"%k_list[i])
    
    print("--- Variation de min_cluster_size---")
    
    for j in range(5,50,5):
        print("min_cluster_size =  %d"%j)
    
        dataset = arff.loadarff(open(path + list_dataset[i] + '.arff', 'r'))
        data = [[x[0],x[1]] for x in dataset[0]]

        clust = hdbscan.HDBSCAN(min_cluster_size=j)
        y_pred = clust.fit_predict(data)

        #print("Score")
        #print(clust.score(data))

        labels = clust.labels_
        print("Indice de Davies-Bouldin")
        print(metrics.davies_bouldin_score(data, labels))

        print("Coefficient de silhouette")
        print(metrics.silhouette_score(data, labels, metric='euclidean'))

        plt.scatter((dataset[0])['x'], (dataset[0])['y'], c=y_pred)
        plt.show()
        
    print("--- Variation de min_samples---")
        
    min_clust_size = [5,30,30,20,5]
    for j in range(5,50,5):
        print("min_samples =  %d"%j)
    
        dataset = arff.loadarff(open(path + list_dataset[i] + '.arff', 'r'))
        data = [[x[0],x[1]] for x in dataset[0]]

        clust = hdbscan.HDBSCAN(min_cluster_size=min_clust_size[i], min_samples=j)
        y_pred = clust.fit_predict(data)

        #print("Score")
        #print(clust.score(data))

        labels = clust.labels_
        print("Indice de Davies-Bouldin")
        print(metrics.davies_bouldin_score(data, labels))

        print("Coefficient de silhouette")
        print(metrics.silhouette_score(data, labels, metric='euclidean'))

        plt.scatter((dataset[0])['x'], (dataset[0])['y'], c=y_pred)
        plt.show()
# Out:
# ----------HDBSCAN----------
# Dataset 0
# convexe_petites_taches
# k = 30
# --- Variation de min_cluster_size---
# min_cluster_size =  5
# Indice de Davies-Bouldin
# 1.4919412687725928
# Coefficient de silhouette
# 0.3376223033430154
# min_cluster_size =  10
# Indice de Davies-Bouldin
# 1.4704762195680403
# Coefficient de silhouette
# 0.3905211617449385
# min_cluster_size =  15
# Indice de Davies-Bouldin
# 1.4093401023690724
# Coefficient de silhouette
# 0.32801617391643856
# min_cluster_size =  20
# Indice de Davies-Bouldin
# 1.3757873401937986
# Coefficient de silhouette
# 0.30578038479803726
# min_cluster_size =  25
# Indice de Davies-Bouldin
# 0.6225901186790864
# Coefficient de silhouette
# 0.01316438555370865
# min_cluster_size =  30
# Indice de Davies-Bouldin
# 0.6545809358947623
# Coefficient de silhouette
# 0.03386346273042333
# min_cluster_size =  35
# Indice de Davies-Bouldin
# 0.6545809358947623
# Coefficient de silhouette
# 0.03386346273042333
# min_cluster_size =  40
# Indice de Davies-Bouldin
# 0.6545809358947623
# Coefficient de silhouette
# 0.03386346273042333
# min_cluster_size =  45
# Indice de Davies-Bouldin
# 1.1204648651215818
# Coefficient de silhouette
# 0.0257533850794809
# --- Variation de min_samples---
# min_samples =  5
# Indice de Davies-Bouldin
# 1.4919412687725928
# Coefficient de silhouette
# 0.3376223033430154
# min_samples =  10
# Indice de Davies-Bouldin
# 1.4704762195680403
# Coefficient de silhouette
# 0.3905211617449385
# min_samples =  15
# Indice de Davies-Bouldin
# 1.4093401023690724
# Coefficient de silhouette
# 0.32801617391643856
# min_samples =  20
# Indice de Davies-Bouldin
# 1.3757873401937986
# Coefficient de silhouette
# 0.30578038479803726
# min_samples =  25
# Indice de Davies-Bouldin
# 1.434490182274154
# Coefficient de silhouette
# 0.20770704769952927
# min_samples =  30
# Indice de Davies-Bouldin
# 0.6545809358947623
# Coefficient de silhouette
# 0.03386346273042333
# min_samples =  35
# Indice de Davies-Bouldin
# 0.6545809358947623
# Coefficient de silhouette
# 0.03386346273042333
# min_samples =  40
# Indice de Davies-Bouldin
# 0.6545809358947623
# Coefficient de silhouette
# 0.03386346273042333
# min_samples =  45
# Indice de Davies-Bouldin
# 1.1204648651215818
# Coefficient de silhouette
# 0.0257533850794809
# Dataset 1
# bruite_convexe
# k = 2
# --- Variation de min_cluster_size---
# min_cluster_size =  5
# Indice de Davies-Bouldin
# 1.7251238467513454
# Coefficient de silhouette
# 0.5601564903478443
# min_cluster_size =  10
# Indice de Davies-Bouldin
# 2.4782588252718685
# Coefficient de silhouette
# 0.5225272115701715
# min_cluster_size =  15
# Indice de Davies-Bouldin
# 2.5185477128813365
# Coefficient de silhouette
# 0.5132930548840616
# min_cluster_size =  20
# Indice de Davies-Bouldin
# 2.5518841345376244
# Coefficient de silhouette
# 0.5144906662076795
# min_cluster_size =  25
# Indice de Davies-Bouldin
# 2.5185477128813365
# Coefficient de silhouette
# 0.5132930548840616
# min_cluster_size =  30
# Indice de Davies-Bouldin
# 2.5185477128813365
# Coefficient de silhouette
# 0.5132930548840616
# min_cluster_size =  35
# Indice de Davies-Bouldin
# 2.5185477128813365
# Coefficient de silhouette
# 0.5132930548840616
# min_cluster_size =  40
# Indice de Davies-Bouldin
# 2.5185477128813365
# Coefficient de silhouette
# 0.5132930548840616
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-4c48d107ec99> in <module>()
#      44
#      45         plt.scatter((dataset[0])['x'], (dataset[0])['y'], c=y_pred)
# ---> 46         plt.show()
#      47
#      48     print("--- Variation de min_samples---")
#
# /home/vanhulle/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# /usr/lib/python3/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# /usr/lib/python3/dist-packages/IPython/core/display.py in display(*objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/lib/python3/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     171             md = None
#     172             try:
# --> 173                 data = formatter(obj)
#     174             except:
#     175                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# /usr/lib/python3/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     215     """show traceback on failed format call"""
#     216     try:
# --> 217         r = method(self, *args, **kwargs)
#     218     except NotImplementedError:
#     219         # don't warn on NotImplementedErrors
#
# /usr/lib/python3/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /home/vanhulle/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2054                         orientation=orientation,
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# /home/vanhulle/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# /home/vanhulle/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# /home/vanhulle/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /home/vanhulle/.local/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# /home/vanhulle/.local/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /home/vanhulle/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /home/vanhulle/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# /home/vanhulle/.local/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /home/vanhulle/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /home/vanhulle/.local/lib/python3.6/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1206
#    1207         for tick in ticks_to_draw:
# -> 1208             tick.draw(renderer)
#    1209
#    1210         # scale up the axis label box to also find the neighbors, not
#
# /home/vanhulle/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /home/vanhulle/.local/lib/python3.6/site-packages/matplotlib/axis.py in draw(self, renderer)
#     295         for artist in [self.gridline, self.tick1line, self.tick2line,
#     296                        self.label1, self.label2]:
# --> 297             artist.draw(renderer)
#     298         renderer.close_group(self.__name__)
#     299         self.stale = False
#
# /home/vanhulle/.local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /home/vanhulle/.local/lib/python3.6/site-packages/matplotlib/text.py in draw(self, renderer)
#     716                     textrenderer.draw_text(gc, x, y, clean_line,
#     717                                            textobj._fontproperties, angle,
# --> 718                                            ismath=ismath, mtext=mtext)
#     719
#     720         gc.restore()
#
# /home/vanhulle/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#     189
#     190         self._renderer.draw_text_image(
# --> 191             font, np.round(x - xd + xo), np.round(y + yd + yo) + 1, angle, gc)
#     192
#     193     def get_text_width_height_descent(self, s, prop, ismath):
#
# <__array_function__ internals> in round_(*args, **kwargs)
#
# /home/vanhulle/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in round_(a, decimals, out)
#    3519     around : equivalent function; see for details.
#    3520     """
# -> 3521     return around(a, decimals=decimals, out=out)
#    3522
#    3523
#
# <__array_function__ internals> in around(*args, **kwargs)
#
# /home/vanhulle/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in around(a, decimals, out)
#    3144
#    3145     """
# -> 3146     return _wrapfunc(a, 'round', decimals=decimals, out=out)
#    3147
#    3148
#
# KeyboardInterrupt:
